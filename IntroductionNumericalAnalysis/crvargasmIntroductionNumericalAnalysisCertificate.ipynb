# %% [markdown]
# #Introduction Numerical Analysis Certificate
# by: *Cristian Camilo Vargas Morales*

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# To see my **[[LinkedIn](https://www.linkedin.com/in/crvargasm/)]**
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
